# %% [markdown]
# <a href="https://colab.research.google.com/github/shikhachourey1992/Mateplotlib/blob/main/Image_classification_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt
import numpy as np
(X_train,y_train),(X_test,y_test)=datasets.cifar10.load_data()

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
classes=[
    'airplane',
    'automobile',
    'bird',
    'cat',
    'dear',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]
plt.figure(figsize=(10,5))
for i in range(10):
  plt.subplot(2,5,i+1)
  plt.imshow(X_train[i])
  plt.title(classes[y_train[i][0]])
  plt.axis('off')
plt.show()
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'dear', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
X_train=X_train/255
X_test=X_test/255

# %%
model=models.Sequential()
model.add(layers.Conv2D(64,(3,3),activation='relu',input_shape=(32,32,3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(128,activation='relu'))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(10,activation='softmax'))
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
histry=model.fit(X_train,y_train,epochs=20,validation_data=(X_test,y_test))
loss,accuracy=model.evaluate(X_test,y_test)
print('accuracy:',accuracy)
prediction=model.predict(X_test)
index=np.argmax(prediction[0])
print(classes[index])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 126s 79ms/step - accuracy: 0.4260 - loss: 1.5676 - val_accuracy: 0.5492 - val_loss: 1.2724
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 141s 78ms/step - accuracy: 0.5760 - loss: 1.1928 - val_accuracy: 0.5907 - val_loss: 1.1528
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 125s 80ms/step - accuracy: 0.6354 - loss: 1.0423 - val_accuracy: 0.6238 - val_loss: 1.0710
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 126s 80ms/step - accuracy: 0.6668 - loss: 0.9421 - val_accuracy: 0.6656 - val_loss: 0.9625
# Epoch 5/20
# ...

# %%
plt.imshow(X_test[0])
plt.show()
image=X_test[20].reshape(1,32,32,3)
prediction=model.predict(image)
print(classes[np.argmax(prediction)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# frog

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
print(y_train[0])
# Out:
# [6]

# %%
# Show 20 images.
plt.figure(figsize=(10,5))
for i in range(20):
  plt.subplot(4,5,i+1)
  plt.imshow(X_train[i])
  plt.title(y_train[i])
  plt.axis('off')
plt.show()

# %%
# Normalize dataset.
X_train/255
X_test/255
# Out:
# array([[[[2.42983468e-03, 1.72241446e-03, 7.53556324e-04],
#          [2.44521338e-03, 1.70703576e-03, 7.22798923e-04],
#          [2.53748558e-03, 1.78392926e-03, 7.84313725e-04],
#          ...,
#          [2.10688197e-03, 1.46097655e-03, 5.53633218e-04],
#          [1.93771626e-03, 1.39946175e-03, 5.53633218e-04],
#          [1.78392926e-03, 1.30718954e-03, 5.07497116e-04]],
#
#         [[2.33756248e-03, 1.72241446e-03, 7.84313725e-04],
#          [2.32218378e-03, 1.69165705e-03, 6.15148020e-04],
#          [2.44521338e-03, 1.75317186e-03, 6.92041522e-04],
#          ...,
#          [2.09150327e-03, 1.46097655e-03, 4.76739715e-04],
#          [1.92233756e-03, 1.39946175e-03, 4.92118416e-04],
#          [1.83006536e-03, 1.35332564e-03, 5.22875817e-04]],
#
#         [[2.32218378e-03, 1.69165705e-03, 7.22798923e-04],
#          [2.32218378e-03, 1.67627835e-03, 5.07497116e-04],
#          [2.42983468e-03, 1.70703576e-03, 5.53633218e-04],
#          ...,
# ...

# %%
# Print dataset shape.
# Print first image label.
# Show 20 images.
# Normalize dataset.
# Print class names.
# Medium
# Increase epochs to 20.
# Change Conv2D filters to 64.
# Add another Dense layer.
# Add one more Conv2D layer.
# Compare accuracy.

# %%
print(classes)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'dear', 'dog', 'frog', 'horse', 'ship', 'truck']

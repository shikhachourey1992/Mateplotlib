# %% [markdown]
# <a href="https://colab.research.google.com/github/shikhachourey1992/Mateplotlib/blob/main/student_scores_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

df=pd.read_csv('student_scores.csv')
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1612/2695492224.py in <cell line: 0>()
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 df=pd.read_csv('student_scores.csv',index=False)
#       7 df
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Exam_Score'], dtype='object')

# %%
x=df[['Hours_Studied']]
y=df['Exam_Score']

# %%
reg=linear_model.LinearRegression()
reg.fit(x,y)
reg.predict([[5]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([66.56363636])

# %%
plt.xlabel('Hours_Studied')
plt.ylabel('Exam_Score')
plt.scatter(x,y,color='red',marker="*")
plt.plot(x,reg.predict(x),color='blue')

# %%
reg.predict([[10]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([96.92727273])

# %%
reg.coef_
# Out:
# array([6.07272727])

# %%
reg.intercept_
# Out:
# np.float64(36.19999999999999)

# %%
#y=mx+b
6.07272727*10+36.19999999999999
# Out:
# 96.92727269999999
